# %%
zip
# Out:
# zip

# %%
from itertools import zip_longest
mk_num = [2,3]
mk_nam = ['неуд', 'уд', 'хор', 'отл']
long_record = zip_longest(mk_num, mk_nam, fillvalue = 'оценка')
print(list(long_record))
# Out:
# [(2, 'неуд'), (3, 'уд'), ('оценка', 'хор'), ('оценка', 'отл')]

# %%
zipped_values = [(2, 'neud', 'peresdacha'), (3, 'ud', '-stip'), (4, 'xor', '=stip')]
num, nam, gh = zip(*zipped_values)
print(num)
print(nam)
print(gh)
#распаковка
# Out:
# (2, 3, 4)
# ('neud', 'ud', 'xor')
# ('peresdacha', '-stip', '=stip')

# %%
matrix = [[1,2,3],[1,2,3]]
matrix_t = [list(i) for i in zip(*matrix)]
print(matrix)
print(matrix_t)
# Out:
# [[1, 2, 3], [1, 2, 3]]
# [[1, 1], [2, 2], [3, 3]]

# %%
import weakref
weakref.ref
# Out:
# weakref.ReferenceType

# %%
import copy
orig_list = [[1,2],[3,4]]
copy_list = copy.copy(orig_list)
deepcopy_list = copy.deepcopy(orig_list)
orig_list
# Out:
# [[1, 2], [3, 4]]

# %%
A = [[10,9,10],[3,3]]
B = copy.deepcopy(A)
B[0][0]=3
print(A)
print(B)
C = copy.copy(A)
C[0][0] = 5
print(A)
print(C)


A = [10,9,10]
B = copy.deepcopy(A)
B[0]=3
print(A)
print(B)
C = copy.copy(A)
C[0] = 5
print(A)
print(C)
#хранение данных во вложенных списках и в просто списках отличааются
#копирование ОПРЕДЕЛЕННЫХ индексов
# Out:
# [[10, 9, 10], [3, 3]]
# [[3, 9, 10], [3, 3]]
# [[5, 9, 10], [3, 3]]
# [[5, 9, 10], [3, 3]]
# [10, 9, 10]
# [3, 9, 10]
# [10, 9, 10]
# [5, 9, 10]

# %%
import numpy as np
a = np.array([1,2,3])
b=a
b[0] = 4

print(b)
print(a)
# Out:
# [4 2 3]
# [4 2 3]

# %%
import numpy as np
import copy
a = np.array([1,2,3])
b=a.copy()
b[0] = 4

print(b)
print(a)
# Out:
# [4 2 3]
# [1 2 3]

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])
c = np.array([7,8,9])
d = np.vstack([a,b,c])

print(d)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])

d = np.hstack([a,b])

print(d)
# Out:
# [1 2 3 4 5 6]

# %%
import numpy as np
a = np.ones((2,4))
b = np.zeros((2,2))

d = np.vstack((a,b))

print(d)
#dstack для 3D матриц
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 5
#       2 a = np.ones((2,4))
#       3 b = np.zeros((2,2))
# ----> 5 d = np.vstack((a,b))
#       7 print(d)
#
# File c:\Users\valer\anaconda3\Lib\site-packages\numpy\core\shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 4 and the array at index 1 has size 2

# %%
import numpy as np
arr = np.array([[1,2],[3,4]])
print(np.linalg.det(arr))
print(arr)
print(np.transpose(arr))
print(np.rot90(arr))
print(np.linalg.inv(arr))
# Out:
# -2.0000000000000004
# [[1 2]
#  [3 4]]
# [[1 3]
#  [2 4]]
# [[2 4]
#  [1 3]]
# [[-2.   1. ]
#  [ 1.5 -0.5]]
# [[-2.   2. ]
#  [ 4.5 -2. ]]

# %%
import numpy as np
arr = np.array([[1,2],[3,4]])
v = np.arange(0,2)
print(arr,v)
np.dot(arr,arr)
np.dot(arr,v)
# Out:
# [[1 2]
#  [3 4]] [0 1]
# array([2, 4])

# %%
import numpy as np
A = np.array([[1,2],[3,4]])
b = np.array([5,7])
print(np.linalg.solve(A,b))
# Out:
# [-3.  4.]

# %%
import matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [20,30,50,40,60]

plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('немного лучше')
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('ещё лучше')
plt.grid(True)
plt.show()

# %%
plt.plot(x,y)
ax = plt.gca()
ax.set_xlim(1,4)
ax.set_ylim(0,60)

ax.set_xticks([1,2,3,4])
ax.set_yticks([0,10,20,30,40,50,60])
plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('ещё лучше')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.plot(x,y)
ax = plt.gca()
ax.set_xlim(1,4)
ax.set_ylim(0,60)

ax.set_xticks([1,2,3,4])
ax.set_yticks([0,10,20,30,40,50,60])

ax.xaxis.set_minor_location(ticker.MultipleLocator(0.5))
ax.yaxis.set_minor_location(ticker.MultipleLocator(5))

plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('ещё лучше')

plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 12
#       9 ax.set_xticks([1,2,3,4])
#      10 ax.set_yticks([0,10,20,30,40,50,60])
# ---> 12 ax.xaxis.set_minor_location(ticker.MultipleLocator(0.5))
#      13 ax.yaxis.set_minor_location(ticker.MultipleLocator(5))
#      15 plt.xlabel('Ось x')
#
# AttributeError: 'XAxis' object has no attribute 'set_minor_location'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.plot(x,y)
ax = plt.gca()
ax.set_xlim(1,4)
ax.set_ylim(0,60)

ax.set_xticks([1,2,3,4])
ax.set_yticks([0,10,20,30,40,50,60])

ax.xaxis.set_minor_location(ticker.FormatStrFormatter('%g'))
ax.yaxis.set_minor_location(ticker.FormatStrFormatter('%g'))

plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('ещё лучше')

plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 12
#       9 ax.set_xticks([1,2,3,4])
#      10 ax.set_yticks([0,10,20,30,40,50,60])
# ---> 12 ax.xaxis.set_minor_location(ticker.FormatStrFormatter('%g'))
#      13 ax.yaxis.set_minor_location(ticker.FormatStrFormatter('%g'))
#      15 plt.xlabel('Ось x')
#
# AttributeError: 'XAxis' object has no attribute 'set_minor_location'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
plt.plot(x,y, color='purple', marker='s', markersize = 10)
"""
ax = plt.gca()
ax.set_xlim(1,4)
ax.set_ylim(0,60)

ax.set_xticks([1,2,3,4])
ax.set_yticks([0,10,20,30,40,50,60])

ax.xaxis.set_minor_location(ticker.MultipleLocator(0.5))
ax.yaxis.set_minor_location(ticker.MultipleLocator(5))
"""
plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('ещё лучше')

plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

x = [1,2,3,4,5]
y = [20,30,50,40,60]

plt.plot(x,y, color='purple', marker='s', markersize = 10)

plt.xlabel('Ось x')
plt.ylabel('Ось y')
plt.title('ещё лучше')

plt.grid(True, which='major', axis='both', linestyle='dashdot')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

x = [1,2,3,4,5]
y = [3,7,4,5,3]

plt.scatter(x,y, color='purple', marker='^')
#plt.plot(x,y, color='purple', marker='s', markersize = 10)

#plt.xlabel('Ось x')
#plt.ylabel('Ось y')
#plt.title('ещё лучше')

#plt.grid(True, which='major', axis='both', linestyle='dashdot')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math
t = np.arange(0,23,553)
y1 = np3g53g905hv4 uwev
x = [1,2,3,4,5]
y = [20,30,50,40,60]
y1 = 
plt.plot(t,y1,'b*',t, y2,'g^', t,y3,'ys')
plt.show()
# Out:
#   Cell In[103], line 6
#     y1 = np3g53g905hv4 uwev
#                        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math

x = np.linspace(0,10,100)
y = np.sin(x)

plt.scatter(x,y, c=x, cmap='BuPu_r')

plt.show()

# %%
x = ['jan','feb','mart','apr','may']
y = [31,25,54,57,11]

plt.bar(x,y, label='dannye c kalendaria', alpha=0.3)
plt.plot(x,y,color='red',marker='o',markersize=7)
plt.legend(loc='best')
plt.show()

# %%
plt.hist # гистограмма
plt.pie # круговая диаграмма
# Out:
# <function matplotlib.pyplot.pie(x: 'ArrayLike', explode: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, colors: 'ColorType | Sequence[ColorType] | None' = None, autopct: 'str | Callable[[float], str] | None' = None, pctdistance: 'float' = 0.6, shadow: 'bool' = False, labeldistance: 'float | None' = 1.1, startangle: 'float' = 0, radius: 'float' = 1, counterclock: 'bool' = True, wedgeprops: 'dict[str, Any] | None' = None, textprops: 'dict[str, Any] | None' = None, center: 'tuple[float, float]' = (0, 0), frame: 'bool' = False, rotatelabels: 'bool' = False, *, normalize: 'bool' = True, hatch: 'str | Sequence[str] | None' = None, data=None) -> 'tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]'>

# %%
plt.pie([0.5,0.5,0.01])
plt.show()

# %%
amount = [18,70,19,19,10]
groups = ['grupp1','grupp2','grupp3','grupp4','grupp5']
colours = ["red", "violet", "yellow", "purple", "blue"]
plt.pie(amount,labels=groups, colors=colours, autopct='%1.f%%')
plt.show()

# %%
amount = [18,70,19,19,10]
groups = ['grupp1','grupp2','grupp3','grupp4','grupp5']
#colours = plt.cm.viridis(np.linspace(0,100))
plt.pie(amount,labels=groups, colors=colours, autopct='%1.f%%')
plt.show()

# %%
amount = [18,70,19,19,10]
groups = ['grupp1','grupp2','grupp3','grupp4','grupp5']
colours = ["red", "violet", "yellow", "purple", "blue"]
plt.figure(figsize=(10,50), dpi=100)
plt.pie(amount,labels=groups, colors=colours, autopct='%1.f%%')
plt.show()

# %%
#plt.savefig('mygraph.png',dpi=300) #сохранение

# %%
days = {
    'sunday':7,
    'monday':1,
    'saturaday':6
}
print(days)
# Out:
# {'sunday': 7, 'monday': 1, 'saturaday': 6}
